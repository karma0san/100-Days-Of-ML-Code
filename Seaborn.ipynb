# %% [markdown]
# <a href="https://colab.research.google.com/github/karma0san/100-Days-Of-ML-Code/blob/master/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to Seaborn**

# %%
# Import required modules
import matplotlib.pyplot as plt
import seaborn as sns

# Load the tips dataset from seaborn
tips = sns.load_dataset("tips")

# %% [markdown]
# **Scatter plot with hex color codes and hue order**

# %%
hue_colors = {"Yes": "#808080", "No": "#00FF00"}
hue_order = ["Yes", "No"]

sns.scatterplot(x="total_bill", 
                y="tip", 
                data=tips, 
                hue="smoker", 
                hue_order=hue_order, # hue item order
                palette=hue_colors) # color customizer

plt.show()

# %% [markdown]
# **Hue with count plots**

# %%
sns.countplot(x="smoker",
              data=tips,
              hue="sex")

plt.show()
